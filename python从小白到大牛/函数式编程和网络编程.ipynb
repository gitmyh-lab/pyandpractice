# %%
number_list = range(1, 11)
number_filter = filter(lambda it: it % 2 == 0, number_list)
print(list(number_filter))
#      filter(function, iterable)
#在function函数中编写过滤条件，如果为True的元素被保留，
#如果为False的元素被过滤掉
# Out:
# [2, 4, 6, 8, 10]

# %%
from functools import reduce
